# %%
import pandas as pd
import duckdb
import os
import os, json
from uuid import uuid4
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

# %%
conn = duckdb.connect('/srv/data/grela_v0-2.duckdb', read_only=True)

# %%
query = """
        SELECT s.grela_id,
               s.sentence_id,
               s.text,
               w.*
        FROM sentences s
                 JOIN works w ON s.grela_id = w.grela_id
        WHERE w.grela_id LIKE 'vulgate_%' \
        """

vulgate_sentences = conn.execute(query).fetchdf()

# %%
len(vulgate_sentences)
# Out:
# 35254

# %%
query = """
        SELECT
            s.grela_id,
            s.sentence_id,
            s.text,
            w.*
        FROM sentences s
        JOIN works w ON s.grela_id = w.grela_id
        WHERE (w.not_before > 1000 AND w.not_before < 1100)
           OR (w.not_after > 1000 AND w.not_after < 1100);
"""

century11 = conn.execute(query).fetchdf()

# %%
century11
# Out:
#          grela_id  sentence_id  \
# 0        cc_10949   cc_10949_0
# 1        cc_10949   cc_10949_1
# 2        cc_10949   cc_10949_2
# 3        cc_10949   cc_10949_3
# 4        cc_10949   cc_10949_4
# ...           ...          ...
# 1357086  cc_10456  cc_10456_27
# 1357087  cc_10456  cc_10456_28
# 1357088  cc_10456  cc_10456_29
# 1357089  cc_10456  cc_10456_30
# 1357090  cc_10456  cc_10456_61
#
#                                                       text grela_source  \
# 0        De gemmis 1637-38 Gemmis a gummi nomen posuere...           cc
# 1             Nomine sed lapidis species signatur utroque;           cc
# 2        Propter quod #lapidum@# titulo liber iste nota...           cc
# 3                                                Prologus.           cc
# 4        Euax rex Arabum legitur scripsisse Neroni, Qui...           cc
# ...                                                    ...          ...
# 1357086  Si uestrae igitur, summe Pater, dignitati plac...           cc
# 1357087  Si enim quod exspecto apud uestram misericordi...           cc
# 1357088  Interim autem usque ad festiuitatem sancti Mic...           cc
# 1357089                                            Ualete.           cc
# 1357090                                            Ualete.           cc
#
#         grela_id_1                       author                  title  \
# 0         cc_10949          Marbodus Redonensis              De gemmis
# 1         cc_10949          Marbodus Redonensis              De gemmis
# 2         cc_10949          Marbodus Redonensis              De gemmis
# 3         cc_10949          Marbodus Redonensis              De gemmis
# 4         cc_10949          Marbodus Redonensis              De gemmis
# ...            ...                          ...                    ...
# 1357086   cc_10456  Raymundus Arnalli1001-1100   Epistola ad Bernardum
# 1357087   cc_10456  Raymundus Arnalli1001-1100   Epistola ad Bernardum
# 1357088   cc_10456  Raymundus Arnalli1001-1100   Epistola ad Bernardum
# 1357089   cc_10456  Raymundus Arnalli1001-1100   Epistola ad Bernardum
# 1357090   cc_10456  Raymundus Arnalli1001-1100   Epistola ad Bernardum
#
#          not_before  not_after lagt_tlg_epithet lagt_genre lagt_provenience  \
# 0            1035.0     1123.0             None       None             None
# 1            1035.0     1123.0             None       None             None
# 2            1035.0     1123.0             None       None             None
# 3            1035.0     1123.0             None       None             None
# 4            1035.0     1123.0             None       None             None
# ...             ...        ...              ...        ...              ...
# 1357086      1001.0     1100.0             None       None             None
# 1357087      1001.0     1100.0             None       None             None
# 1357088      1001.0     1100.0             None       None             None
# 1357089      1001.0     1100.0             None       None             None
# 1357090      1001.0     1100.0             None       None             None
#
#         noscemus_place noscemus_genre noscemus_discipline title_short  \
# 0                 None           None                None        None
# 1                 None           None                None        None
# 2                 None           None                None        None
# 3                 None           None                None        None
# 4                 None           None                None        None
# ...                ...            ...                 ...         ...
# 1357086           None           None                None        None
# 1357087           None           None                None        None
# 1357088           None           None                None        None
# 1357089           None           None                None        None
# 1357090           None           None                None        None
#
#          emlap_noscemus_id place_publication place_geonames  author_viaf  \
# 0                      NaN              None           None          NaN
# 1                      NaN              None           None          NaN
# 2                      NaN              None           None          NaN
# 3                      NaN              None           None          NaN
# 4                      NaN              None           None          NaN
# ...                    ...               ...            ...          ...
# 1357086                NaN              None           None          NaN
# 1357087                NaN              None           None          NaN
# 1357088                NaN              None           None          NaN
# 1357089                NaN              None           None          NaN
# 1357090                NaN              None           None          NaN
#
#          title_viaf  date_random  token_count
# 0               NaN       1038.0         6111
# 1               NaN       1038.0         6111
# 2               NaN       1038.0         6111
# 3               NaN       1038.0         6111
# 4               NaN       1038.0         6111
# ...             ...          ...          ...
# 1357086         NaN       1023.0         1022
# 1357087         NaN       1023.0         1022
# 1357088         NaN       1023.0         1022
# 1357089         NaN       1023.0         1022
# 1357090         NaN       1023.0         1022
#
# [1357091 rows x 23 columns]

# %%
len(century11)#%%
query = """
WITH subcorpora AS (
    SELECT
        SUBSTR(grela_id, 0, INSTR(grela_id, '_')) AS subcorpus,
        COUNT(DISTINCT grela_id) AS works_N,
        COUNT(DISTINCT sentence_id) AS sentences_N,
        COUNT(*) AS tokens_N
    FROM tokens
    GROUP BY subcorpus
)
SELECT * FROM subcorpora
ORDER BY subcorpus;
"""

# Execute the query and fetch as a pandas DataFrame
subcorpus_stats_df = conn.execute(query).fetchdf()

# %%
query = """
SELECT *
FROM tokens
WHERE grela_id LIKE 'vulgate_tlg0031%' OR grela_id LIKE 'vulgate_tlg0527%';
"""

result_df = conn.execute(query).fetchdf()

# %%
subcorpus_stats_df
# Out:
#   subcorpus  works_N  sentences_N   tokens_N
# 0        cc     7819     11835457  201939293
# 1     emlap       73       220846    3495212
# 2      lagt     1957      2703678   35808742
# 3  noscemus      996     11802783  139401899
# 4   vulgate       73        35254     603091

# %%
markdown_table = subcorpus_stats_df.set_index("subcorpus").applymap("{:,.0f}".format).to_markdown()
print(markdown_table)
# Out:
# | subcorpus   | works_N   | sentences_N   | tokens_N    |
# |:------------|:----------|:--------------|:------------|
# | cc          | 7,819     | 11,835,457    | 201,939,293 |
# | emlap       | 73        | 220,846       | 3,495,212   |
# | lagt        | 1,957     | 2,703,678     | 35,808,742  |
# | noscemus    | 996       | 11,802,783    | 139,401,899 |
# | vulgate     | 73        | 35,254        | 603,091     |
# /tmp/ipykernel_54758/3358712856.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   markdown_table = subcorpus_stats_df.set_index("subcorpus").applymap("{:,.0f}".format).to_markdown()

# %%
def get_grouped_token_data_with_metadata(conn, lemma: str, pos_tags: list):
    """
    Return one row per matching token (lemma + POS filter) with:
      • full sentence token list
      • ±10-token concordance window
      • minimal work-level metadata
    """

    pos_placeholder = ", ".join(f"'{tag}'" for tag in pos_tags)

    query = f"""
    /*──────────────── 1. anchor tokens ────────────────*/
    WITH target_matches AS (
        SELECT
            t.sentence_id,
            t.grela_id,
            s.position                     AS sentence_position,
            t.token_id                     AS target_token_id,
            t.char_start                   AS target_char_start,
            t.char_end                     AS target_char_end
        FROM tokens   AS t
        JOIN sentences AS s USING (sentence_id)
        WHERE  t.lemma = ?
          AND  t.pos   IN ({pos_placeholder})
    ),

    /*──────────────── 2. ±1-sentence context ──────────*/
    context_3sents AS (
        SELECT
            tm.sentence_id,
            STRING_AGG(s.text, ' | ' ORDER BY s.position) AS context_3sents
        FROM target_matches tm
        JOIN sentences s
          ON s.grela_id = tm.grela_id
         AND s.position BETWEEN tm.sentence_position - 1
                            AND tm.sentence_position + 1
        GROUP BY tm.sentence_id
    ),

    /*──────────────── 3. full token list per sentence ─*/
    sentence_tokens AS (
        SELECT
            sentence_id,
            LIST(
              STRUCT_PACK(
                 token_id    := token_id,
                 token_text  := token_text,
                 lemma       := lemma,
                 pos         := pos,
                 char_start  := char_start,
                 char_end    := char_end,
                 sentence_id := sentence_id
              )
              ORDER BY token_id
            ) AS tokens
        FROM tokens
        WHERE sentence_id IN (SELECT DISTINCT sentence_id FROM target_matches)
        GROUP BY sentence_id
    ),

    /*──────────────── 4. ±10-token concordance window ─*/
    concordance_tokens AS (
        SELECT
            tm.sentence_id,
            tm.target_token_id,
            LIST(
              STRUCT_PACK(
                 token_id    := ct.token_id,
                 token_text  := ct.token_text,
                 lemma       := ct.lemma,
                 pos         := ct.pos,
                 char_start  := ct.char_start,
                 char_end    := ct.char_end,
                 sentence_id := ct.sentence_id
              )
              ORDER BY ct.token_id
            ) AS concordance_tokens
        FROM target_matches tm
        JOIN tokens        ct
          ON ct.grela_id = tm.grela_id
         AND ct.token_id BETWEEN tm.target_token_id - 10
                            AND tm.target_token_id + 10
        GROUP BY tm.sentence_id, tm.target_token_id
    )

    /*──────────────── 5. final projection (custom column order) ─────*/
    SELECT
        w.author,
        w.title,
        tm.grela_id AS grela_id,
        tm.sentence_id,
        s.text                    AS sentence_text,
        c3.context_3sents,

        st.tokens                AS tokens,
        ct.concordance_tokens    AS concordance_tokens,

        w.not_before,
        w.not_after,
        w.date_random,
        w.lagt_genre,
        w.lagt_provenience,
        w.noscemus_genre,
        w.noscemus_discipline,

        tm.target_token_id,
        tm.target_char_start,
        tm.target_char_end

    FROM target_matches      tm
    JOIN sentences           s   USING (sentence_id)
    JOIN works               w   ON w.grela_id = tm.grela_id
    LEFT JOIN context_3sents c3  USING (sentence_id)
    LEFT JOIN sentence_tokens st USING (sentence_id)
    LEFT JOIN concordance_tokens ct
           ON  ct.sentence_id    = tm.sentence_id
          AND ct.target_token_id = tm.target_token_id
    ORDER BY tm.sentence_id, tm.target_token_id;
    """

    return conn.execute(query, [lemma]).fetchdf()

# %%
result_df = get_grouped_token_data_with_metadata(conn, lemma="deus", pos_tags=["NOUN", "PROPN", "ADJ"])
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
len(result_df)
# Out:
# 189258

# %%
result_df.sample(10)
# Out:
#                                 author  \
# 150753                Sorbière, Samuel
# 6914    Sicardus Cremonensis1155–1215
# 131092                      Lactantius
# 105032                Ioachim de Flore
# 6614                 Alanus de Insulis
# 73660           Augustinus Hipponensis
# 35540                     Balde, Iacob
# 28285                Giannozzo Manetti
# 105908                  Benzo Albensis
# 117216                     Odo, Pietro
#
#                                                     title         grela_id  \
# 150753  Ad virum illustrem Henricum Ludovicum Habertum...  noscemus_693174
# 6914                                            Chronicon         cc_11809
# 131092                    Divinarum institutionum liber V          cc_6811
# 105032                        Introduzione all'Apocalisse         cc_15557
# 6614                                    Contra haereticos         cc_11755
# 73660                            Epistulae 185-270 [CSEL]         cc_14954
# 35540                                             Poemata         cc_13993
# 28285          De dignitate et excellentia hominis (I-II)         cc_13026
# 105908              Ad Heinricum IV imperatorem libri VII         cc_16653
# 117216                                            Carmina         cc_19839
#
#                   sentence_id  \
# 150753  noscemus_693174_18570
# 6914             cc_11809_956
# 131092            cc_6811_859
# 105032           cc_15557_175
# 6614            cc_11755_3580
# 73660           cc_14954_8016
# 35540          cc_13993_20708
# 28285            cc_13026_383
# 105908          cc_16653_3029
# 117216           cc_19839_431
#
#                                             sentence_text  \
# 150753  nullam enim nouistis, nisi profectam a nem imm...
# 6914           #non est conueniens, ut homo judicet deos;
# 131092  Quid aliud dicam quam miseros, qui praedonum s...
# 105032  [b.] Significata sunt hec omnia in octo illis ...
# 6614    dii uero gentium alieni dii dicuntur, qui fals...
# 73660   ingrati, scelesti, inreligiosi, sine affection...
# 35540   Cum somnus, Deorum blandissimum munus, superfu...
# 28285   Qui quidem, cum per totum septimum et octauum ...
# 105908  Potest esse plasma dei, sol aut stella aliqua ...
# 117216  Ergo deo similem sese fecisse merendo, Qui pot...
#
#                                            context_3sents  \
# 150753  Praetereo autem quod habes Uoluptatum credo, n...
# 6914    Lxxxi) @#. | #non est conueniens, ut homo judi...
# 131092  nitunturque summa diligentia, ne qua sit anima...
# 105032  Septima uero pars de iudicio agit et de gloria...
# 6614    Nec est Deus alienus, qui uere est Deus; | Nec...
# 73660   inquit, se ipsos amantes, amatores pecuniae, e...
# 35540   mirabatur, si alius esset ab eo, quem ipse can...
# 28285   Sed, ut alia multa omittamus que a plerisque c...
# 105908  Est autem in potestate liberi arbitrii Homines...
# 117216  numquam per uos errauerit ille, Per se quem nu...
#
#                                                    tokens  \
# 150753  [{'token_id': 122102765, 'token_text': 'nullam...
# 6914    [{'token_id': 266035572, 'token_text': '#', 'l...
# 131092  [{'token_id': 298852647, 'token_text': 'Quid',...
# 105032  [{'token_id': 298000901, 'token_text': '[', 'l...
# 6614    [{'token_id': 364744567, 'token_text': 'dii', ...
# 73660   [{'token_id': 270227728, 'token_text': 'ingrat...
# 35540   [{'token_id': 353308466, 'token_text': 'Cum', ...
# 28285   [{'token_id': 222036668, 'token_text': 'Qui', ...
# 105908  [{'token_id': 374107227, 'token_text': 'Potest...
# 117216  [{'token_id': 380471196, 'token_text': 'Ergo',...
#
#                                        concordance_tokens  not_before  \
# 150753  [{'token_id': 122102785, 'token_text': ',', 'l...      1658.0
# 6914    [{'token_id': 266035570, 'token_text': '#', 'l...      1155.0
# 131092  [{'token_id': 298852650, 'token_text': 'quam',...       250.0
# 105032  [{'token_id': 298000916, 'token_text': 'secund...      1132.0
# 6614    [{'token_id': 364744566, 'token_text': ';', 'l...      1128.0
# 73660   [{'token_id': 270227746, 'token_text': 'prodit...       354.0
# 35540   [{'token_id': 353308459, 'token_text': 'candid...      1604.0
# 28285   [{'token_id': 222036736, 'token_text': 'ut', '...      1396.0
# 105908  [{'token_id': 374107220, 'token_text': ',', 'l...      1010.0
# 117216  [{'token_id': 380471200, 'token_text': 'feciss...         NaN
#
#         not_after  date_random lagt_genre lagt_provenience noscemus_genre  \
# 150753     1658.0       1658.0       None             None      Biography
# 6914       1215.0       1174.0       None             None           None
# 131092      325.0        291.0       None             None           None
# 105032     1202.0       1161.0       None             None           None
# 6614       1203.0       1149.0       None             None           None
# 73660       430.0        390.0       None             None           None
# 35540      1668.0       1665.0       None             None           None
# 28285      1459.0       1446.0       None             None           None
# 105908     1085.0       1033.0       None             None           None
# 117216        NaN          NaN       None             None           None
#
#                                       noscemus_discipline  target_token_id  \
# 150753  Mathematics, Physics, Astronomy/Astrology/Cosm...        122102795
# 6914                                                 None        266035580
# 131092                                               None        298852660
# 105032                                               None        298000926
# 6614                                                 None        364744576
# 73660                                                None        270227756
# 35540                                                None        353308469
# 28285                                                None        222036746
# 105908                                               None        374107230
# 117216                                               None        380471210
#
#         target_char_start  target_char_end
# 150753                158              162
# 6914                   37               41
# 131092                 81               85
# 105032                134              137
# 6614                   48               51
# 73660                 167              170
# 35540                  12               18
# 28285                 466              469
# 105908                 19               22
# 117216                 74               77
