# %%
# paste your api key when prompted
from getpass import getpass
import os

if not os.environ.get("EINFRA_API_KEY"):
    os.environ["EINFRA_API_KEY"] = getpass("EINFRA API key: ")

# %%
import os
import time
import random
import threading
import warnings
import requests
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

# Suppress warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['CUDA_VISIBLE_DEVICES'] = ''
os.environ['TOKENIZERS_PARALLELISM'] = 'false'
warnings.filterwarnings('ignore')

# Suppress TensorFlow warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Suppress INFO and WARNING messages
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'  # Disable oneDNN optimizations
os.environ['CUDA_VISIBLE_DEVICES'] = ''   # Use CPU only (optional)
os.environ['TOKENIZERS_PARALLELISM'] = 'false'  # Disable tokenizer parallelism warnings

# Suppress other warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
df = pd.read_parquet('../data/register_matches_v1.parquet')
df
# Out:
#         sentence_id                                               text  \
# 2412  cc_10265_2412  #posui te hodie super gentes et regna ut euell...
# 3489  cc_10265_3489  #quoniam data est a Domino potestas uobis, et ...
# 3480  cc_10265_3480  His quidem qui secundum patientiam boni operis...
# 5322  cc_10265_5322  #tu es Petrus et super hanc petram aedificabo ...
# 3823  cc_10265_3823  #secundum multitudinem dolorum meorum in corde...
# ...             ...                                                ...
# 3332  cc_10265_3332  De caetero rogamus te et multum admonemus ut o...
# 2461  cc_10265_2461  Praeterea monemus ut studeatis terram uestram,...
# 2158  cc_10265_2158  Praeterea si sancta Romana mater Ecclesia cont...
# 5112  cc_10265_5112  et ejus conjugem, ut tam insigni patrono reuer...
# 5431  cc_10265_5431  isti in se peccantibus cito ignoscunt, Deum of...
#
#                                            vulgate_text     score  \
# 2412  ecce constitui te hodie super gentes et super ...  0.899080
# 3489  quoniam data est a Domino potestas vobis et vi...  0.866035
# 3480  his quidem qui secundum patientiam boni operis...  0.865040
# 5322  et ego dico tibi quia tu es Petrus et super ha...  0.860747
# 3823  secundum multitudinem dolorum meorum in corde ...  0.856230
# ...                                                 ...       ...
# 3332  ut haec tibi verbis illius diceremus obsecro u...  0.600273
# 2461  omnem causam quae venerit ad vos fratrum vestr...  0.600268
# 2158  sed in testimonium inter nos et vos et subolem...  0.600197
# 5112  vestes sanctas in ministerio Aaron sacerdoti e...  0.600177
# 5431  et usque dum non peccarent in conspectu Dei su...  0.600007
#
#                 citation                   vulgate_sentence_id
# 2412       Jeremiah 1.10   vulgate_tlg0527.tlg049.obi-lat:1.10
# 3489          Wisdom 6.4    vulgate_tlg0527.tlg033.obi-lat:6.4
# 3480          Romans 2.7    vulgate_tlg0031.tlg006.obi-lat:2.7
# 5322       Matthew 16.18  vulgate_tlg0031.tlg001.obi-lat:16.18
# 3823        Psalms 93.19  vulgate_tlg0527.tlg027.obi-lat:93.19
# ...                  ...                                   ...
# 3332       Genesis 50.17  vulgate_tlg0527.tlg001.obi-lat:50.17
# 2461  2 Chronicles 19.10  vulgate_tlg0527.tlg016.obi-lat:19.10
# 2158        Joshua 22.27  vulgate_tlg0527.tlg006.obi-lat:22.27
# 5112        Exodus 31.10  vulgate_tlg0527.tlg002.obi-lat:31.10
# 5431         Judith 5.21   vulgate_tlg0527.tlg020.obi-lat:5.21
#
# [574 rows x 6 columns]

# %%
requests.get("https://llm.ai.e-infra.cz/v1/models",
             headers={"Authorization": f"Bearer {os.environ['API_KEY']}"}).json()
# Out:
# {'data': [{'id': 'mistral-medium-3.5',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'multilingual-e5-large-instruct',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'qwen3.8-flash-next',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'deepseek-thinking',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'whisper-large-v3',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'kimi',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'glm',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'kimi-k3',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'qwen3.8-27b',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'mini',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'coder',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'deepseek-v4-flash-thinking',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai',
#    'max_input_tokens': 1000000,
#    'max_output_tokens': 8192},
#   {'id': 'nrp',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'glm-5',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'deepseek-v4.1-flash-thinking',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'mxbai-embed-large:latest',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'qwen3.5',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'glm-5.3',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'gemma4',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'deepseek-v4-flash',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai',
#    'mode': 'chat',
#    'max_input_tokens': 1000000,
#    'max_output_tokens': 8192},
#   {'id': 'qwen3-embedding-4b',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'thinker',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'qwen3-reranker-4b',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'gpt-oss-120b',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'auto-llm',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'all-proxy-models',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'agentic',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'deepseek',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'glm-5.2',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'command-a',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'auto-llm-heuristic',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'nomic-embed-text-v2-moe',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'nomic-embed-text-v1.5',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'},
#   {'id': 'qwen3.5-int4',
#    'object': 'model',
#    'created': 1677610602,
#    'owned_by': 'openai'}],
#  'object': 'list'}

# %%
# ─────────────────────────── 2. LLM system prompt with descriptions ──────────────────────────
SYSTEM = """
You are a Latin scholar, that specializes in the translation from Latin to English.

Your will translate each given Latin sentence into modern day English. Be precise and accurate.

Respond **only with the translation**. Don't output any explanations.
""".strip()

# ─────────────────────────── 3. Few-shot examples ──────────────────────────
FEWSHOT = """
Original: crescite vero in gratia et in cognitione Domini nostri et salvatoris Iesu Christi ipsi gloria et nunc et in die aeternitatis amen.
Translation: But grow in the grace and knowledge of our Lord and Savior Jesus Christ. To him be glory both now and forever! Amen.

Original: certissime ergo sciat omnis domus Israhel quia et Dominum eum et Christum Deus fecit hunc Iesum quem vos crucifixistis
Translation: Therefore let all Israel be assured of this: God has made this Jesus, whom you crucified, both Lord and Messiah.

Original: humiliamini igitur sub potenti manu Dei ut vos exaltet in tempore visitationis
Translation: Humble yourselves, therefore, under God’s mighty hand, that he may lift you up in due time.

Original: unde debuit per omnia fratribus similare ut misericors fieret et fidelis pontifex ad Deum ut repropitiaret delicta populi
Translation: For this reason he had to be made like them, fully human in every way, in order that he might become a merciful and faithful high priest in service to God, and that he might make atonement for the sins of the people.

Original: {}
Translation:
""".strip()

# ─────────────────────────── 4. Translation function (OpenAI format + retry on 429) ──────────
_sem = threading.BoundedSemaphore(3)   # provider allows max 4 parallel – keep headroom

def classify_desc(passage: str,
                  *,
                  model_name:  str = "kimi",
                  url:         str = "https://llm.ai.e-infra.cz/v1/chat/completions",
                  api_key:     str | None = None,
                  temperature: float = 0.0,
                  timeout:     int   = 300,
                  max_retries: int   = 10) -> str | None:

    if pd.isna(passage) or passage is None:
        return None

    api_key = api_key or os.environ["EINFRA_API_KEY"]
    prompt = FEWSHOT.format(passage.strip())

    payload = {
        "model": model_name,
        "messages": [
            {"role": "system", "content": SYSTEM},
            {"role": "user",   "content": prompt},
        ],
        "temperature": temperature,
        "max_tokens": 200,
    }

    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {api_key}",
    }

    for attempt in range(max_retries):
        with _sem:
            try:
                resp = requests.post(url, json=payload, headers=headers, timeout=timeout)
            except requests.RequestException as e:
                print("⛔ LLM request failed:", e)
                return None

        if resp.status_code == 429:   # rate limited → back off and retry
            retry_after = resp.headers.get("Retry-After")
            wait = float(retry_after) if retry_after else min(2 ** attempt, 60)
            time.sleep(wait + random.uniform(0, 0.5))
            continue

        if resp.status_code != 200:
            # NOTE: body intentionally not printed – provider may echo the API key
            print(f"⛔ LLM HTTP {resp.status_code}")
            return None

        try:
            return resp.json()["choices"][0]["message"]["content"].strip()
        except Exception:
            print("⚠︎ Unexpected LLM response structure")
            return None

    print("⛔ Gave up after retries (rate limited)")
    return None


# ─────────────────────────── 5. Batch runner with checkpointing ──────────────────────────
def classify_many(passages, max_workers=3, checkpoint_path="../data/translation_checkpoint.pkl"):
    if os.path.exists(checkpoint_path):
        results = pd.read_pickle(checkpoint_path)["translation"].tolist()
        # resume after last successful translation so failed (None) rows get retried
        start = next((i for i, v in enumerate(reversed(results)) if v is not None),
                     len(results))
        start = len(results) - start
        results = results[:start]
        print(f"Resuming from checkpoint, {start} lines already processed.")
    else:
        results, start = [], 0

    total = len(passages)
    passages = list(passages)

    with ThreadPoolExecutor(max_workers=max_workers) as ex:
        fut_to_i = {ex.submit(classify_desc, p): i
                    for i, p in enumerate(passages[start:], start)}
        completed = start
        for fut in as_completed(fut_to_i):
            i = fut_to_i[fut]
            while len(results) <= i:
                results.append(None)
            results[i] = fut.result()
            completed += 1
            if completed % 10 == 0 or completed == total:
                print(f"Processed {completed}/{total}")
                pd.DataFrame({"text": passages[:completed],
                              "translation": results[:completed]}).to_pickle(checkpoint_path)

    pd.DataFrame({"text": passages, "translation": results}).to_pickle(checkpoint_path)
    return results

# %%
subcorp = df[:10]
classify_many(subcorp["text"], max_workers=3)
# Out:
# Processed 10/10
# ['', '', '', '', '', '', '', '', '', '']
