# %%
import pandas as pd
import duckdb
import os
import os, json
from uuid import uuid4
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

# %%
conn = duckdb.connect('/srv/data/grela_v0-2.duckdb', read_only=True)

# %%
query = """
        SELECT w.*
        FROM works w
        """
works_df = conn.execute(query).fetchdf()

# %%
works_df.shape
# Out:
# (11117, 20)

# %%
works_df.columns
# Out:
# Index(['grela_source', 'grela_id', 'author', 'title', 'not_before',
#        'not_after', 'lagt_tlg_epithet', 'lagt_genre', 'lagt_provenience',
#        'noscemus_place', 'noscemus_genre', 'noscemus_discipline',
#        'title_short', 'emlap_noscemus_id', 'place_publication',
#        'place_geonames', 'author_viaf', 'title_viaf', 'date_random',
#        'token_count'],
#       dtype='object')

# %%
works_df.sample(10)
# Out:
#       grela_source             grela_id  \
# 10509     noscemus      noscemus_694618
# 7912            cc              cc_7940
# 7305            cc              cc_7338
# 1721          lagt  lagt_tlg2003.tlg003
# 8457            cc              cc_8479
# 10694     noscemus      noscemus_657733
# 5747            cc             cc_16869
# 3864            cc             cc_11671
# 4609            cc             cc_13157
# 558           lagt  lagt_tlg0035.tlg002
#
#                                            author  \
# 10509   Kirchmaier, Georg Kaspar,Leutmann, Martin
# 7912               Gregorius Turonensisc.538–594
# 7305   Auctor incertus (Augustinus Hipponensis?)
# 1721                           Julian the Emperor
# 8457                     Auctor incertus (Beda?)
# 10694   Petrus Peregrinus,Gasser, Achilles Pirmin
# 5747                               Wipo Presbyter
# 3864             Reinerus S. Laurentii Leodiensis
# 4609                  Marulus Spalatensis, Marcus
# 558                                       Moschus
#
#                                                    title  not_before  \
# 10509  Quod Deus bene vertat. Ex physicis disputation...      1659.0
# 7912                                  Historia Francorum       538.0
# 7305                   Sermones suppositii de Scripturis         NaN
# 1721   The Heroic Deeds of the Emperor Constantius, o...       331.0
# 8457                    Interpretatio nominum Hebraeorum         NaN
# 10694  Petri Peregrini Maricurtensis de magnete seu r...      1558.0
# 5747                                               Opera      1050.0
# 3864               De claris scriptoribus monasterii sui      1110.0
# 4609                        Ad Georgium Sisgoreum [1477]      1450.0
# 558                                               Εὐρώπη      -149.0
#
#        not_after      lagt_tlg_epithet lagt_genre lagt_provenience  \
# 10509     1659.0                  None       None             None
# 7912       594.0                  None       None             None
# 7305         NaN                  None       None             None
# 1721       363.0  ['Philosophici/-ae']         []            pagan
# 8457         NaN                  None       None             None
# 10694     1558.0                  None       None             None
# 5747      1050.0                  None       None             None
# 3864      1182.0                  None       None             None
# 4609      1524.0                  None       None             None
# 558       -149.0          ['Bucolici']         []            pagan
#
#       noscemus_place noscemus_genre                  noscemus_discipline  \
# 10509     Wittenberg   Dissertation           Meteorology/Earth sciences
# 7912            None           None                                 None
# 7305            None           None                                 None
# 1721            None           None                                 None
# 8457            None           None                                 None
# 10694       Augsburg         Letter  Physics, Meteorology/Earth sciences
# 5747            None           None                                 None
# 3864            None           None                                 None
# 4609            None           None                                 None
# 558             None           None                                 None
#
#       title_short  emlap_noscemus_id place_publication place_geonames  \
# 10509        None                NaN              None           None
# 7912         None                NaN              None           None
# 7305         None                NaN              None           None
# 1721         None                NaN              None           None
# 8457         None                NaN              None           None
# 10694        None                NaN              None           None
# 5747         None                NaN              None           None
# 3864         None                NaN              None           None
# 4609         None                NaN              None           None
# 558          None                NaN              None           None
#
#        author_viaf  title_viaf  date_random  token_count
# 10509          NaN         NaN       1659.0         5066
# 7912           NaN         NaN        541.0       155702
# 7305           NaN         NaN          NaN       162873
# 1721           NaN         NaN        347.0        16397
# 8457           NaN         NaN          NaN         1320
# 10694          NaN         NaN       1558.0        10241
# 5747           NaN         NaN       1050.0        21647
# 3864           NaN         NaN       1139.0        11125
# 4609           NaN         NaN       1505.0          267
# 558            NaN         NaN       -149.0         1345

# %%
query = """
        SELECT w.*
        FROM works w
        WHERE w.grela_id LIKE 'vulgate_%'
        """
works_vulgate_df = conn.execute(query).fetchdf()
# Out:
#   grela_source                        grela_id author  \
# 0      vulgate  vulgate_tlg0031.tlg001.obi-lat   None
# 1      vulgate  vulgate_tlg0031.tlg002.obi-lat   None
# 2      vulgate  vulgate_tlg0031.tlg003.obi-lat   None
# 3      vulgate  vulgate_tlg0031.tlg004.obi-lat   None
# 4      vulgate  vulgate_tlg0031.tlg005.obi-lat   None
# 5      vulgate  vulgate_tlg0031.tlg006.obi-lat   None
# 6      vulgate  vulgate_tlg0031.tlg007.obi-lat   None
# 7      vulgate  vulgate_tlg0031.tlg008.obi-lat   None
# 8      vulgate  vulgate_tlg0031.tlg009.obi-lat   None
# 9      vulgate  vulgate_tlg0031.tlg010.obi-lat   None
#
#                      title  not_before  not_after lagt_tlg_epithet lagt_genre  \
# 0        Vulgate - Matthew         NaN        NaN             None       None
# 1           Vulgate - Mark         NaN        NaN             None       None
# 2           Vulgate - Luke         NaN        NaN             None       None
# 3           Vulgate - John         NaN        NaN             None       None
# 4           Vulgate - Acts         NaN        NaN             None       None
# 5         Vulgate - Romans         NaN        NaN             None       None
# 6  Vulgate - 1 Corinthians         NaN        NaN             None       None
# 7  Vulgate - 2 Corinthians         NaN        NaN             None       None
# 8      Vulgate - Galatians         NaN        NaN             None       None
# 9      Vulgate - Ephesians         NaN        NaN             None       None
#
#   lagt_provenience noscemus_place noscemus_genre noscemus_discipline  \
# 0             None           None           None                None
# 1             None           None           None                None
# 2             None           None           None                None
# 3             None           None           None                None
# 4             None           None           None                None
# 5             None           None           None                None
# 6             None           None           None                None
# 7             None           None           None                None
# 8             None           None           None                None
# 9             None           None           None                None
#
#   title_short  emlap_noscemus_id place_publication place_geonames  \
# 0        None                NaN              None           None
# 1        None                NaN              None           None
# 2        None                NaN              None           None
# 3        None                NaN              None           None
# 4        None                NaN              None           None
# 5        None                NaN              None           None
# 6        None                NaN              None           None
# 7        None                NaN              None           None
# 8        None                NaN              None           None
# 9        None                NaN              None           None
#
#    author_viaf  title_viaf  date_random  token_count
# 0          NaN         NaN          NaN            0
# 1          NaN         NaN          NaN            0
# 2          NaN         NaN          NaN            0
# 3          NaN         NaN          NaN            0
# 4          NaN         NaN          NaN            0
# 5          NaN         NaN          NaN            0
# 6          NaN         NaN          NaN            0
# 7          NaN         NaN          NaN            0
# 8          NaN         NaN          NaN            0
# 9          NaN         NaN          NaN            0

# %%
works_vulgate_df.sample(10)
# Out:
#    grela_source                        grela_id author  \
# 42      vulgate  vulgate_tlg0527.tlg018.obi-lat   None
# 38      vulgate  vulgate_tlg0527.tlg014.obi-lat   None
# 57      vulgate  vulgate_tlg0527.tlg037.obi-lat   None
# 72      vulgate  vulgate_tlg0527.tlg056.obi-lat   None
# 52      vulgate  vulgate_tlg0527.tlg032.obi-lat   None
# 67      vulgate  vulgate_tlg0527.tlg047.obi-lat   None
# 50      vulgate  vulgate_tlg0527.tlg029.obi-lat   None
# 34      vulgate  vulgate_tlg0527.tlg010.obi-lat   None
# 70      vulgate  vulgate_tlg0527.tlg051.obi-lat   None
# 17      vulgate  vulgate_tlg0031.tlg018.obi-lat   None
#
#                      title  not_before  not_after lagt_tlg_epithet lagt_genre  \
# 42      Vulgate - Nehemiah         NaN        NaN             None       None
# 38       Vulgate - 2 Kings         NaN        NaN             None       None
# 57          Vulgate - Amos         NaN        NaN             None       None
# 72        Vulgate - Daniel         NaN        NaN             None       None
# 52           Vulgate - Job         NaN        NaN             None       None
# 67       Vulgate - Malachi         NaN        NaN             None       None
# 50      Vulgate - Proverbs         NaN        NaN             None       None
# 34          Vulgate - Ruth         NaN        NaN             None       None
# 70  Vulgate - Lamentations         NaN        NaN             None       None
# 17      Vulgate - Philemon         NaN        NaN             None       None
#
#    lagt_provenience noscemus_place noscemus_genre noscemus_discipline  \
# 42             None           None           None                None
# 38             None           None           None                None
# 57             None           None           None                None
# 72             None           None           None                None
# 52             None           None           None                None
# 67             None           None           None                None
# 50             None           None           None                None
# 34             None           None           None                None
# 70             None           None           None                None
# 17             None           None           None                None
#
#    title_short  emlap_noscemus_id place_publication place_geonames  \
# 42        None                NaN              None           None
# 38        None                NaN              None           None
# 57        None                NaN              None           None
# 72        None                NaN              None           None
# 52        None                NaN              None           None
# 67        None                NaN              None           None
# 50        None                NaN              None           None
# 34        None                NaN              None           None
# 70        None                NaN              None           None
# 17        None                NaN              None           None
#
#     author_viaf  title_viaf  date_random  token_count
# 42          NaN         NaN          NaN            0
# 38          NaN         NaN          NaN            0
# 57          NaN         NaN          NaN            0
# 72          NaN         NaN          NaN            0
# 52          NaN         NaN          NaN            0
# 67          NaN         NaN          NaN            0
# 50          NaN         NaN          NaN            0
# 34          NaN         NaN          NaN            0
# 70          NaN         NaN          NaN            0
# 17          NaN         NaN          NaN            0

# %%
query = """
        SELECT s.grela_id,
               s.sentence_id,
               s.text,
               w.*
        FROM sentences s
                 JOIN works w ON s.grela_id = w.grela_id
        WHERE w.grela_id LIKE 'vulgate_%' \
        """

vulgate_sentences = conn.execute(query).fetchdf()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       1 query = """
#       2         SELECT s.grela_id,
#       3                s.sentence_id,
#    (...)
#       8         WHERE w.grela_id LIKE 'vulgate_%' \
#       9         """
# ---> 11 vulgate_sentences = conn.execute(query).fetchdf()
#
# NameError: name 'conn' is not defined

# %%
len(vulgate_sentences)
# Out:
# 35254

# %%
vulgate_sentences[5000:5010]
# Out:
#                             grela_id                          sentence_id  \
# 5000  vulgate_tlg0031.tlg006.obi-lat  vulgate_tlg0031.tlg006.obi-lat:8.33
# 5001  vulgate_tlg0031.tlg006.obi-lat  vulgate_tlg0031.tlg006.obi-lat:8.34
# 5002  vulgate_tlg0031.tlg006.obi-lat  vulgate_tlg0031.tlg006.obi-lat:8.35
# 5003  vulgate_tlg0031.tlg006.obi-lat  vulgate_tlg0031.tlg006.obi-lat:8.36
# 5004  vulgate_tlg0031.tlg006.obi-lat  vulgate_tlg0031.tlg006.obi-lat:8.37
# 5005  vulgate_tlg0031.tlg006.obi-lat  vulgate_tlg0031.tlg006.obi-lat:8.38
# 5006  vulgate_tlg0031.tlg006.obi-lat  vulgate_tlg0031.tlg006.obi-lat:8.39
# 5007  vulgate_tlg0031.tlg006.obi-lat   vulgate_tlg0031.tlg006.obi-lat:9.1
# 5008  vulgate_tlg0031.tlg006.obi-lat   vulgate_tlg0031.tlg006.obi-lat:9.2
# 5009  vulgate_tlg0031.tlg006.obi-lat   vulgate_tlg0031.tlg006.obi-lat:9.3
#
#                                                    text grela_source  \
# 5000  quis accusabit adversus electos Dei Deus qui i...      vulgate
# 5001  quis est qui condemnet Christus Iesus qui mort...      vulgate
# 5002  quis nos separabit a caritate Christi tribulat...      vulgate
# 5003  sicut scriptum est quia propter te mortificamu...      vulgate
# 5004  sed in his omnibus superamus propter eum qui d...      vulgate
# 5005  certus sum enim quia neque mors neque vita neq...      vulgate
# 5006  neque altitudo neque profundum neque creatura ...      vulgate
# 5007  veritatem dico in Christo non mentior testimon...      vulgate
# 5008  quoniam tristitia est mihi magna et continuus ...      vulgate
# 5009  optabam enim ipse ego anathema esse a Christo ...      vulgate
#
#                           grela_id_1 author             title  not_before  \
# 5000  vulgate_tlg0031.tlg006.obi-lat   None  Vulgate - Romans         NaN
# 5001  vulgate_tlg0031.tlg006.obi-lat   None  Vulgate - Romans         NaN
# 5002  vulgate_tlg0031.tlg006.obi-lat   None  Vulgate - Romans         NaN
# 5003  vulgate_tlg0031.tlg006.obi-lat   None  Vulgate - Romans         NaN
# 5004  vulgate_tlg0031.tlg006.obi-lat   None  Vulgate - Romans         NaN
# 5005  vulgate_tlg0031.tlg006.obi-lat   None  Vulgate - Romans         NaN
# 5006  vulgate_tlg0031.tlg006.obi-lat   None  Vulgate - Romans         NaN
# 5007  vulgate_tlg0031.tlg006.obi-lat   None  Vulgate - Romans         NaN
# 5008  vulgate_tlg0031.tlg006.obi-lat   None  Vulgate - Romans         NaN
# 5009  vulgate_tlg0031.tlg006.obi-lat   None  Vulgate - Romans         NaN
#
#       not_after lagt_tlg_epithet lagt_genre lagt_provenience noscemus_place  \
# 5000        NaN             None       None             None           None
# 5001        NaN             None       None             None           None
# 5002        NaN             None       None             None           None
# 5003        NaN             None       None             None           None
# 5004        NaN             None       None             None           None
# 5005        NaN             None       None             None           None
# 5006        NaN             None       None             None           None
# 5007        NaN             None       None             None           None
# 5008        NaN             None       None             None           None
# 5009        NaN             None       None             None           None
#
#      noscemus_genre noscemus_discipline title_short  emlap_noscemus_id  \
# 5000           None                None        None                NaN
# 5001           None                None        None                NaN
# 5002           None                None        None                NaN
# 5003           None                None        None                NaN
# 5004           None                None        None                NaN
# 5005           None                None        None                NaN
# 5006           None                None        None                NaN
# 5007           None                None        None                NaN
# 5008           None                None        None                NaN
# 5009           None                None        None                NaN
#
#      place_publication place_geonames  author_viaf  title_viaf  date_random  \
# 5000              None           None          NaN         NaN          NaN
# 5001              None           None          NaN         NaN          NaN
# 5002              None           None          NaN         NaN          NaN
# 5003              None           None          NaN         NaN          NaN
# 5004              None           None          NaN         NaN          NaN
# 5005              None           None          NaN         NaN          NaN
# 5006              None           None          NaN         NaN          NaN
# 5007              None           None          NaN         NaN          NaN
# 5008              None           None          NaN         NaN          NaN
# 5009              None           None          NaN         NaN          NaN
#
#       token_count
# 5000            0
# 5001            0
# 5002            0
# 5003            0
# 5004            0
# 5005            0
# 5006            0
# 5007            0
# 5008            0
# 5009            0

# %%
query = """
        SELECT
            s.grela_id,
            s.sentence_id,
            s.text,
            w.*
        FROM sentences s
        JOIN works w ON s.grela_id = w.grela_id
        WHERE (w.not_before > 1000 AND w.not_before < 1100)
           OR (w.not_after > 1000 AND w.not_after < 1100);
"""

century11 = conn.execute(query).fetchdf()

# %%
len(century11)
# Out:
# 1357091

# %%
query = """
SELECT *
FROM tokens
WHERE grela_id LIKE 'vulgate_tlg0031%' OR grela_id LIKE 'vulgate_tlg0527%';
"""

vulgate_tokens_df = conn.execute(query).fetchdf()
len(vulgate_tokens_df)
# Out:
# 603091

# %%
vulgate_tokens_df[1000:1020]
# Out:
#                               sentence_id                        grela_id  \
# 1000  vulgate_tlg0031.tlg001.obi-lat:3.12  vulgate_tlg0031.tlg001.obi-lat
# 1001  vulgate_tlg0031.tlg001.obi-lat:3.12  vulgate_tlg0031.tlg001.obi-lat
# 1002  vulgate_tlg0031.tlg001.obi-lat:3.12  vulgate_tlg0031.tlg001.obi-lat
# 1003  vulgate_tlg0031.tlg001.obi-lat:3.12  vulgate_tlg0031.tlg001.obi-lat
# 1004  vulgate_tlg0031.tlg001.obi-lat:3.13  vulgate_tlg0031.tlg001.obi-lat
# 1005  vulgate_tlg0031.tlg001.obi-lat:3.13  vulgate_tlg0031.tlg001.obi-lat
# 1006  vulgate_tlg0031.tlg001.obi-lat:3.13  vulgate_tlg0031.tlg001.obi-lat
# 1007  vulgate_tlg0031.tlg001.obi-lat:3.13  vulgate_tlg0031.tlg001.obi-lat
# 1008  vulgate_tlg0031.tlg001.obi-lat:3.13  vulgate_tlg0031.tlg001.obi-lat
# 1009  vulgate_tlg0031.tlg001.obi-lat:3.13  vulgate_tlg0031.tlg001.obi-lat
# 1010  vulgate_tlg0031.tlg001.obi-lat:3.13  vulgate_tlg0031.tlg001.obi-lat
# 1011  vulgate_tlg0031.tlg001.obi-lat:3.13  vulgate_tlg0031.tlg001.obi-lat
# 1012  vulgate_tlg0031.tlg001.obi-lat:3.13  vulgate_tlg0031.tlg001.obi-lat
# 1013  vulgate_tlg0031.tlg001.obi-lat:3.13  vulgate_tlg0031.tlg001.obi-lat
# 1014  vulgate_tlg0031.tlg001.obi-lat:3.13  vulgate_tlg0031.tlg001.obi-lat
# 1015  vulgate_tlg0031.tlg001.obi-lat:3.13  vulgate_tlg0031.tlg001.obi-lat
# 1016  vulgate_tlg0031.tlg001.obi-lat:3.13  vulgate_tlg0031.tlg001.obi-lat
# 1017  vulgate_tlg0031.tlg001.obi-lat:3.14  vulgate_tlg0031.tlg001.obi-lat
# 1018  vulgate_tlg0031.tlg001.obi-lat:3.14  vulgate_tlg0031.tlg001.obi-lat
# 1019  vulgate_tlg0031.tlg001.obi-lat:3.14  vulgate_tlg0031.tlg001.obi-lat
#
#           token_text             lemma    pos  char_start  char_end  token_id
# 1000           autem             autem  CCONJ         103       108     13005
# 1001        conburet           comburo   VERB         109       117     13006
# 1002            igni             ignis   NOUN         118       122     13007
# 1003  inextinguibili  inexstinguibilis    ADJ         123       137     13008
# 1004            tunc              tunc    ADV           0         4     13009
# 1005           venit             uenio   VERB           5        10     13010
# 1006           Iesus             Iesus  PROPN          11        16     13011
# 1007               a                ab    ADP          17        18     13012
# 1008        Galilaea          Galilaea  PROPN          19        27     13013
# 1009              in                in    ADP          28        30     13014
# 1010        Iordanen          Iordanes  PROPN          31        39     13015
# 1011              ad                ad    ADP          40        42     13016
# 1012        Iohannem           Ioannes  PROPN          43        51     13017
# 1013              ut                ut  SCONJ          52        54     13018
# 1014    baptizaretur           baptizo   VERB          55        67     13019
# 1015              ab                ab    ADP          68        70     13020
# 1016              eo                is   PRON          71        73     13021
# 1017        Iohannes           Ioannes  PROPN           0         8     13022
# 1018           autem             autem  CCONJ           9        14     13023
# 1019      prohibebat          prohibeo   VERB          15        25     13024

# %%
def get_grouped_token_data_with_metadata(conn, lemma: str, pos_tags: list):
    """
    Return one row per matching token (lemma + POS filter) with:
      • full sentence token list
      • ±10-token concordance window
      • minimal work-level metadata
    """

    pos_placeholder = ", ".join(f"'{tag}'" for tag in pos_tags)

    query = f"""
    /*──────────────── 1. anchor tokens ────────────────*/
    WITH target_matches AS (
        SELECT
            t.sentence_id,
            t.grela_id,
            s.position                     AS sentence_position,
            t.token_id                     AS target_token_id,
            t.char_start                   AS target_char_start,
            t.char_end                     AS target_char_end
        FROM tokens   AS t
        JOIN sentences AS s USING (sentence_id)
        WHERE  t.lemma = ?
          AND  t.pos   IN ({pos_placeholder})
    ),

    /*──────────────── 2. ±1-sentence context ──────────*/
    context_3sents AS (
        SELECT
            tm.sentence_id,
            STRING_AGG(s.text, ' | ' ORDER BY s.position) AS context_3sents
        FROM target_matches tm
        JOIN sentences s
          ON s.grela_id = tm.grela_id
         AND s.position BETWEEN tm.sentence_position - 1
                            AND tm.sentence_position + 1
        GROUP BY tm.sentence_id
    ),

    /*──────────────── 3. full token list per sentence ─*/
    sentence_tokens AS (
        SELECT
            sentence_id,
            LIST(
              STRUCT_PACK(
                 token_id    := token_id,
                 token_text  := token_text,
                 lemma       := lemma,
                 pos         := pos,
                 char_start  := char_start,
                 char_end    := char_end,
                 sentence_id := sentence_id
              )
              ORDER BY token_id
            ) AS tokens
        FROM tokens
        WHERE sentence_id IN (SELECT DISTINCT sentence_id FROM target_matches)
        GROUP BY sentence_id
    ),

    /*──────────────── 4. ±10-token concordance window ─*/
    concordance_tokens AS (
        SELECT
            tm.sentence_id,
            tm.target_token_id,
            LIST(
              STRUCT_PACK(
                 token_id    := ct.token_id,
                 token_text  := ct.token_text,
                 lemma       := ct.lemma,
                 pos         := ct.pos,
                 char_start  := ct.char_start,
                 char_end    := ct.char_end,
                 sentence_id := ct.sentence_id
              )
              ORDER BY ct.token_id
            ) AS concordance_tokens
        FROM target_matches tm
        JOIN tokens        ct
          ON ct.grela_id = tm.grela_id
         AND ct.token_id BETWEEN tm.target_token_id - 10
                            AND tm.target_token_id + 10
        GROUP BY tm.sentence_id, tm.target_token_id
    )

    /*──────────────── 5. final projection (custom column order) ─────*/
    SELECT
        w.author,
        w.title,
        tm.grela_id AS grela_id,
        tm.sentence_id,
        s.text                    AS sentence_text,
        c3.context_3sents,

        st.tokens                AS tokens,
        ct.concordance_tokens    AS concordance_tokens,

        w.not_before,
        w.not_after,
        w.date_random,
        w.lagt_genre,
        w.lagt_provenience,
        w.noscemus_genre,
        w.noscemus_discipline,

        tm.target_token_id,
        tm.target_char_start,
        tm.target_char_end

    FROM target_matches      tm
    JOIN sentences           s   USING (sentence_id)
    JOIN works               w   ON w.grela_id = tm.grela_id
    LEFT JOIN context_3sents c3  USING (sentence_id)
    LEFT JOIN sentence_tokens st USING (sentence_id)
    LEFT JOIN concordance_tokens ct
           ON  ct.sentence_id    = tm.sentence_id
          AND ct.target_token_id = tm.target_token_id
    ORDER BY tm.sentence_id, tm.target_token_id;
    """

    return conn.execute(query, [lemma]).fetchdf()

# %%
result_df = get_grouped_token_data_with_metadata(conn, lemma="deus", pos_tags=["NOUN", "PROPN"])
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
pd.DataFrame(result_df["concordance_tokens"].iloc[0].tolist())
# Out:
#      token_id  token_text      lemma    pos  char_start  char_end  \
# 0   183835477    scholari  scholaris   VERB          25        33
# 1   183835478      ferula     ferula   NOUN          34        40
# 2   183835479   erudiendi     erudio   VERB          41        50
# 3   183835480      essent        sum    AUX          51        57
# 4   183835481           ,          ,  PUNCT          57        58
# 5   183835482        quia       quia  SCONJ          59        63
# 6   183835483    ignauiae   ignauius   NOUN          64        72
# 7   183835484           ,          ,  PUNCT          72        73
# 8   183835485   socordiae   socordia   NOUN          74        83
# 9   183835486          et         et  CCONJ          84        86
# 10  183835487         deo       deus   NOUN          87        90
# 11  183835488         suo       suus    DET          91        94
# 12  183835489      uentri     uenter   NOUN          95       101
# 13  183835490       manus      manus   NOUN         102       107
# 14  183835491    dederunt         do   VERB         108       116
# 15  183835492           ,          ,  PUNCT         116       117
# 16  183835493         dum        dum  SCONJ         118       121
# 17  183835494     instrui    instruo   VERB         122       129
# 18  183835495   refugiunt    refugio   VERB         130       139
# 19  183835496          ad         ad    ADP         140       142
# 20  183835497  grauitatem   grauitas   NOUN         143       153
#
#      sentence_id
# 0   cc_10003_335
# 1   cc_10003_335
# 2   cc_10003_335
# 3   cc_10003_335
# 4   cc_10003_335
# 5   cc_10003_335
# 6   cc_10003_335
# 7   cc_10003_335
# 8   cc_10003_335
# 9   cc_10003_335
# 10  cc_10003_335
# 11  cc_10003_335
# 12  cc_10003_335
# 13  cc_10003_335
# 14  cc_10003_335
# 15  cc_10003_335
# 16  cc_10003_335
# 17  cc_10003_335
# 18  cc_10003_335
# 19  cc_10003_335
# 20  cc_10003_335

# %%
len(result_df)
# Out:
# 189155

# %%
pd.DataFrame(result_df.iloc[0]["tokens"].tolist())
# Out:
#      token_id   token_text     lemma    pos  char_start  char_end  \
# 0   183835471           At        at  CCONJ           0         2
# 1   183835472         uero      uero    ADV           3         7
# 2   183835473           hi       hic    DET           8        10
# 3   183835474          qui       qui   PRON          11        14
# 4   183835475        adhuc     adhuc    ADV          15        20
# ..        ...          ...       ...    ...         ...       ...
# 64  183835535        uocum       uox   NOUN         389       394
# 65  183835536          uel       uel  CCONJ         395       398
# 66  183835537  quaestionum  quaestio   NOUN         399       410
# 67  183835538  nouitatibus   nouitas   NOUN         411       422
# 68  183835539            :         :  PUNCT         422       423
#
#      sentence_id
# 0   cc_10003_335
# 1   cc_10003_335
# 2   cc_10003_335
# 3   cc_10003_335
# 4   cc_10003_335
# ..           ...
# 64  cc_10003_335
# 65  cc_10003_335
# 66  cc_10003_335
# 67  cc_10003_335
# 68  cc_10003_335
#
# [69 rows x 7 columns]
