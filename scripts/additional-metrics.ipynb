# %%
import pandas as pd

df = pd.read_parquet('../data/register_matches_v1.parquet')
df
# Out:
#         sentence_id                                               text  \
# 2412  cc_10265_2412  #posui te hodie super gentes et regna ut euell...
# 3489  cc_10265_3489  #quoniam data est a Domino potestas uobis, et ...
# 3480  cc_10265_3480  His quidem qui secundum patientiam boni operis...
# 5322  cc_10265_5322  #tu es Petrus et super hanc petram aedificabo ...
# 3823  cc_10265_3823  #secundum multitudinem dolorum meorum in corde...
# ...             ...                                                ...
# 3332  cc_10265_3332  De caetero rogamus te et multum admonemus ut o...
# 2461  cc_10265_2461  Praeterea monemus ut studeatis terram uestram,...
# 2158  cc_10265_2158  Praeterea si sancta Romana mater Ecclesia cont...
# 5112  cc_10265_5112  et ejus conjugem, ut tam insigni patrono reuer...
# 5431  cc_10265_5431  isti in se peccantibus cito ignoscunt, Deum of...
#
#                                            vulgate_text     score  \
# 2412  ecce constitui te hodie super gentes et super ...  0.899080
# 3489  quoniam data est a Domino potestas vobis et vi...  0.866035
# 3480  his quidem qui secundum patientiam boni operis...  0.865040
# 5322  et ego dico tibi quia tu es Petrus et super ha...  0.860747
# 3823  secundum multitudinem dolorum meorum in corde ...  0.856230
# ...                                                 ...       ...
# 3332  ut haec tibi verbis illius diceremus obsecro u...  0.600273
# 2461  omnem causam quae venerit ad vos fratrum vestr...  0.600268
# 2158  sed in testimonium inter nos et vos et subolem...  0.600197
# 5112  vestes sanctas in ministerio Aaron sacerdoti e...  0.600177
# 5431  et usque dum non peccarent in conspectu Dei su...  0.600007
#
#                 citation                   vulgate_sentence_id
# 2412       Jeremiah 1.10   vulgate_tlg0527.tlg049.obi-lat:1.10
# 3489          Wisdom 6.4    vulgate_tlg0527.tlg033.obi-lat:6.4
# 3480          Romans 2.7    vulgate_tlg0031.tlg006.obi-lat:2.7
# 5322       Matthew 16.18  vulgate_tlg0031.tlg001.obi-lat:16.18
# 3823        Psalms 93.19  vulgate_tlg0527.tlg027.obi-lat:93.19
# ...                  ...                                   ...
# 3332       Genesis 50.17  vulgate_tlg0527.tlg001.obi-lat:50.17
# 2461  2 Chronicles 19.10  vulgate_tlg0527.tlg016.obi-lat:19.10
# 2158        Joshua 22.27  vulgate_tlg0527.tlg006.obi-lat:22.27
# 5112        Exodus 31.10  vulgate_tlg0527.tlg002.obi-lat:31.10
# 5431         Judith 5.21   vulgate_tlg0527.tlg020.obi-lat:5.21
#
# [574 rows x 6 columns]

# %%
#jaccard similarity
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt_tab')

def jaccard_similarity(set1, set2):
    intersection = set1.intersection(set2)
    union = set1.union(set2)
    return len(intersection) / len(union) if len(union) > 0 else 0.0

def rowwise_jaccard(list1, list2):
    similarities = []
    for s1, s2 in zip(list1, list2):
        tokens1 = set(word_tokenize(s1.lower()))
        tokens2 = set(word_tokenize(s2.lower()))
        sim = jaccard_similarity(tokens1, tokens2)
        similarities.append(sim)
    return similarities

# Example usage:
df['jaccard_sim'] = rowwise_jaccard(df['text'],df['vulgate_text'])
# Out:
# [nltk_data] Downloading package punkt_tab to /home/tvrzj/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#         sentence_id                                               text  \
# 2412  cc_10265_2412  #posui te hodie super gentes et regna ut euell...
# 3489  cc_10265_3489  #quoniam data est a Domino potestas uobis, et ...
# 3480  cc_10265_3480  His quidem qui secundum patientiam boni operis...
# 5322  cc_10265_5322  #tu es Petrus et super hanc petram aedificabo ...
# 3823  cc_10265_3823  #secundum multitudinem dolorum meorum in corde...
# ...             ...                                                ...
# 3332  cc_10265_3332  De caetero rogamus te et multum admonemus ut o...
# 2461  cc_10265_2461  Praeterea monemus ut studeatis terram uestram,...
# 2158  cc_10265_2158  Praeterea si sancta Romana mater Ecclesia cont...
# 5112  cc_10265_5112  et ejus conjugem, ut tam insigni patrono reuer...
# 5431  cc_10265_5431  isti in se peccantibus cito ignoscunt, Deum of...
#
#                                            vulgate_text     score  \
# 2412  ecce constitui te hodie super gentes et super ...  0.899080
# 3489  quoniam data est a Domino potestas vobis et vi...  0.866035
# 3480  his quidem qui secundum patientiam boni operis...  0.865040
# 5322  et ego dico tibi quia tu es Petrus et super ha...  0.860747
# 3823  secundum multitudinem dolorum meorum in corde ...  0.856230
# ...                                                 ...       ...
# 3332  ut haec tibi verbis illius diceremus obsecro u...  0.600273
# 2461  omnem causam quae venerit ad vos fratrum vestr...  0.600268
# 2158  sed in testimonium inter nos et vos et subolem...  0.600197
# 5112  vestes sanctas in ministerio Aaron sacerdoti e...  0.600177
# 5431  et usque dum non peccarent in conspectu Dei su...  0.600007
#
#                 citation                   vulgate_sentence_id  jaccard_sim
# 2412       Jeremiah 1.10   vulgate_tlg0527.tlg049.obi-lat:1.10     0.545455
# 3489          Wisdom 6.4    vulgate_tlg0527.tlg033.obi-lat:6.4     0.608696
# 3480          Romans 2.7    vulgate_tlg0031.tlg006.obi-lat:2.7     0.666667
# 5322       Matthew 16.18  vulgate_tlg0031.tlg001.obi-lat:16.18     0.560000
# 3823        Psalms 93.19  vulgate_tlg0527.tlg027.obi-lat:93.19     0.578947
# ...                  ...                                   ...          ...
# 3332       Genesis 50.17  vulgate_tlg0527.tlg001.obi-lat:50.17     0.053333
# 2461  2 Chronicles 19.10  vulgate_tlg0527.tlg016.obi-lat:19.10     0.090909
# 2158        Joshua 22.27  vulgate_tlg0527.tlg006.obi-lat:22.27     0.045455
# 5112        Exodus 31.10  vulgate_tlg0527.tlg002.obi-lat:31.10     0.047619
# 5431         Judith 5.21   vulgate_tlg0527.tlg020.obi-lat:5.21     0.068966
#
# [574 rows x 7 columns]

# %%
def levenshtein_distance(s1, s2):
    # Create a matrix to store distances
    matrix = [[0] * (len(s2) + 1) for _ in range(len(s1) + 1)]

    # Initialize first row and column
    for i in range(len(s1) + 1):
        matrix[i][0] = i
    for j in range(len(s2) + 1):
        matrix[0][j] = j

    # Calculate Levenshtein distance
    for i in range(1, len(s1) + 1):
        for j in range(1, len(s2) + 1):
            if s1[i-1] == s2[j-1]:
                matrix[i][j] = matrix[i-1][j-1]
            else:
                matrix[i][j] = min(
                    matrix[i-1][j] + 1,    # deletion
                    matrix[i][j-1] + 1,    # insertion
                    matrix[i-1][j-1] + 1   # substitution
                )

    return matrix[len(s1)][len(s2)]

def rowwise_levenshtein_similarity(list1, list2):
    similarities = []
    for s1, s2 in zip(list1, list2):
        if not s1 or not s2:
            similarities.append(0.0)
            continue
        max_length = max(len(s1), len(s2))
        if max_length == 0:
            similarities.append(1.0)
            continue
        distance = levenshtein_distance(s1, s2)
        similarity = 1 - (distance / max_length)
        similarities.append(similarity)
    return similarities

df['levenshtein_sim'] = rowwise_levenshtein_similarity(df['text'], df['vulgate_text'])

# %%
df
# Out:
#         sentence_id                                               text  \
# 2412  cc_10265_2412  #posui te hodie super gentes et regna ut euell...
# 3489  cc_10265_3489  #quoniam data est a Domino potestas uobis, et ...
# 3480  cc_10265_3480  His quidem qui secundum patientiam boni operis...
# 5322  cc_10265_5322  #tu es Petrus et super hanc petram aedificabo ...
# 3823  cc_10265_3823  #secundum multitudinem dolorum meorum in corde...
# ...             ...                                                ...
# 3332  cc_10265_3332  De caetero rogamus te et multum admonemus ut o...
# 2461  cc_10265_2461  Praeterea monemus ut studeatis terram uestram,...
# 2158  cc_10265_2158  Praeterea si sancta Romana mater Ecclesia cont...
# 5112  cc_10265_5112  et ejus conjugem, ut tam insigni patrono reuer...
# 5431  cc_10265_5431  isti in se peccantibus cito ignoscunt, Deum of...
#
#                                            vulgate_text     score  \
# 2412  ecce constitui te hodie super gentes et super ...  0.899080
# 3489  quoniam data est a Domino potestas vobis et vi...  0.866035
# 3480  his quidem qui secundum patientiam boni operis...  0.865040
# 5322  et ego dico tibi quia tu es Petrus et super ha...  0.860747
# 3823  secundum multitudinem dolorum meorum in corde ...  0.856230
# ...                                                 ...       ...
# 3332  ut haec tibi verbis illius diceremus obsecro u...  0.600273
# 2461  omnem causam quae venerit ad vos fratrum vestr...  0.600268
# 2158  sed in testimonium inter nos et vos et subolem...  0.600197
# 5112  vestes sanctas in ministerio Aaron sacerdoti e...  0.600177
# 5431  et usque dum non peccarent in conspectu Dei su...  0.600007
#
#                 citation                   vulgate_sentence_id  jaccard_sim  \
# 2412       Jeremiah 1.10   vulgate_tlg0527.tlg049.obi-lat:1.10     0.545455
# 3489          Wisdom 6.4    vulgate_tlg0527.tlg033.obi-lat:6.4     0.608696
# 3480          Romans 2.7    vulgate_tlg0031.tlg006.obi-lat:2.7     0.666667
# 5322       Matthew 16.18  vulgate_tlg0031.tlg001.obi-lat:16.18     0.560000
# 3823        Psalms 93.19  vulgate_tlg0527.tlg027.obi-lat:93.19     0.578947
# ...                  ...                                   ...          ...
# 3332       Genesis 50.17  vulgate_tlg0527.tlg001.obi-lat:50.17     0.053333
# 2461  2 Chronicles 19.10  vulgate_tlg0527.tlg016.obi-lat:19.10     0.090909
# 2158        Joshua 22.27  vulgate_tlg0527.tlg006.obi-lat:22.27     0.045455
# 5112        Exodus 31.10  vulgate_tlg0527.tlg002.obi-lat:31.10     0.047619
# 5431         Judith 5.21   vulgate_tlg0527.tlg020.obi-lat:5.21     0.068966
#
#       levenshtein_sim
# 2412         0.772358
# 3489         0.936508
# 3480         0.927928
# 5322         0.781250
# 3823         0.833333
# ...               ...
# 3332         0.304348
# 2461         0.279343
# 2158         0.259542
# 5112         0.228216
# 5431         0.300971
#
# [574 rows x 8 columns]
